# %%
import altair as alt
from sklearn import datasets
from util.common import *
import pandas as pd
import numpy as np

np.random.seed(42)

# %%
# Create a sample dataframe
df = pd.DataFrame({'category': ['A', 'B', 'A', 'C', 'A', 'B']})

# Use the enhanced value_counts with percentages
df['category'].value_counts_pct()

# %%
# minimal altair chart example to test setup
alt.Chart(df).mark_bar().encode(x='category', y='count()')

# %%
submit_answer(1, "Done")
